# %% [markdown]
# # Quantum Control Geometry v0.3.1 clean-environment reproduction
#
# This notebook runs the public clean-environment reproduction entry point for the frozen `v0.3.1` scientific release.
#
# No PASQAL account or password is required. The runner checks out the frozen tag, verifies the expected commit and SHA-256 snapshot, runs the regression tests, and recomputes the complete formal certificate twice.
#
# Expected frozen commit:
#
# ```text
# 284974c9f6b952f4e114c8c5bdc9c2c299c4065c
# ```
#
# Scope: this is a reproduction of the same frozen model, code, and certificate pipeline. It is not independent scientific validation or PASQAL hardware evidence.

# %%
# !python - <<'PY'
from pathlib import Path
import urllib.request

url = "https://raw.githubusercontent.com/papasop/quantum-control-geometry/main/scripts/standalone/external_reproduce_v0_3_1.py"
target = Path("/content/external_reproduce_v0_3_1.py") if Path("/content").is_dir() else Path("external_reproduce_v0_3_1.py")
target.write_bytes(urllib.request.urlopen(url).read())
print(f"Downloaded {url}")
print(f"Saved to {target}")
PY

# %%
# %run external_reproduce_v0_3_1.py
